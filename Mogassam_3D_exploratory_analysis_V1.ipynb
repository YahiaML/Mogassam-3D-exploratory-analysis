# %% [markdown]
# <a href="https://colab.research.google.com/github/YahiaML/Mogassam-3D-exploratory-analysis.V1/blob/main/Mogassam_3D_exploratory_analysis_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_excel("/content/Coordinates.xlsx")

# %%
df.head()
# Out:
#        Type  File_Number  X-axis  Y-axis  Z-axis  In_Normal_Case Error_range  \
# 0  Bridge 2            2      12      -1       0            True      Normal
# 1  Bridge 2            3     -38     -13       4           False      Mediam
# 2  Bridge 2            4     -18       6      -1            True      Normal
# 3  Bridge 2            5     -69     -12       8           False        High
# 4  Bridge 2            6      20     -33      -6           False      Mediam
#
#   Notes
# 0   NAN
# 1   NAN
# 2   NAN
# 3   NAN
# 4   NAN

# %%
# whole data analysis

#Filtring
true_orient = df[df["In_Normal_Case"] == True]
false_orient = df[df["In_Normal_Case"] == False]
#Counting True/False orientation overall:
true_count = true_orient["In_Normal_Case"].count() 
false_count = false_orient["In_Normal_Case"].count() 

#Calculating the Percentage of True/False orientation overall:
true_present = (true_count / df["In_Normal_Case"].count()) * 100
false_present = (false_count / df["In_Normal_Case"].count()) *100

# Calculating overall means:
x_axis_mean = df["X-axis"].mean()
y_axis_mean = df["Y-axis"].mean()
z_axis_mean = df["Z-axis"].mean()

# overall Summation:
x_axis_sum = df["X-axis"].sum()
y_axis_sum = df["Y-axis"].sum()
z_axis_sum = df["Z-axis"].sum()

# Printing Results
print("* "*20, "All the data","* "*20)
print(" ")
print("Percentage of True orientation =",round(true_present,2), "%", "(count = {})".format(true_count))
print("Percentage of False orientation =", round(false_present,2), "%", "(count = {})".format(false_count))
print("X-axis: mean =",round(x_axis_mean,2), " ,sum =",round(x_axis_sum,2))
print("Y-axis: mean =",round(y_axis_mean,2), " ,sum =",round(y_axis_sum,2))
print("Z-axis: mean =",round(z_axis_mean,2), " ,sum =",round(z_axis_sum,2))
# Out:
# * * * * * * * * * * * * * * * * * * * *  All the data * * * * * * * * * * * * * * * * * * * *
#
# Percentage of True orientation = 55.41 % (count = 819)
# Percentage of False orientation = 44.59 % (count = 659)
# X-axis: mean = 7.94  ,sum = 11733
# Y-axis: mean = 1.32  ,sum = 1948
# Z-axis: mean = 3.66  ,sum = 5408

# %%
# Formatting tools:
class format:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

#Choosing the type
for type_ in list(df["Type"].unique()):

  #Filtring
  type_filter = df[df["Type"] == type_]
  true_orient = type_filter[type_filter["In_Normal_Case"] == True]
  false_orient = type_filter[type_filter["In_Normal_Case"] == False]
  
#--------------------------------------------------- Overall ---------------------------------------------------#

  #Counting True/False orientation overall:
  true_count = true_orient["In_Normal_Case"].count() 
  false_count = false_orient["In_Normal_Case"].count()  

  #Calculating the Percentage of True/False orientation overall:
  true_present = (true_count / type_filter["In_Normal_Case"].count()) * 100
  false_present = (false_count / type_filter["In_Normal_Case"].count()) *100
  
  # Calculating overall means:

  x_axis_mean = type_filter["X-axis"].mean()
  y_axis_mean = type_filter["Y-axis"].mean()
  z_axis_mean = type_filter["Z-axis"].mean()

  # overall Summation:
  x_axis_sum = type_filter["X-axis"].sum()
  y_axis_sum = type_filter["Y-axis"].sum()
  z_axis_sum = type_filter["Z-axis"].sum()

#--------------------------------------------------- True ---------------------------------------------------#

  # Calculating overall True means:

  true_x_axis_mean = true_orient["X-axis"].mean()
  true_y_axis_mean = true_orient["Y-axis"].mean()
  true_z_axis_mean = true_orient["Z-axis"].mean()

  # overall True Summation:
  true_x_axis_sum = true_orient["X-axis"].sum()
  true_y_axis_sum = true_orient["Y-axis"].sum()
  true_z_axis_sum = true_orient["Z-axis"].sum()

  # O.B.T.O axis means:
  true_obto_x_axis_mean = true_orient[true_orient["Error_range"] == "O.B.T.O"]["X-axis"].mean()
  true_obto_y_axis_mean = true_orient[true_orient["Error_range"] == "O.B.T.O"]["Y-axis"].mean()
  true_obto_z_axis_mean = true_orient[true_orient["Error_range"] == "O.B.T.O"]["Z-axis"].mean()

  # O.B.T.O axis Summation:
  true_obto_x_axis_sum = true_orient[true_orient["Error_range"] == "O.B.T.O"]["X-axis"].sum()
  true_obto_y_axis_sum = true_orient[true_orient["Error_range"] == "O.B.T.O"]["Y-axis"].sum()
  true_obto_z_axis_sum = true_orient[true_orient["Error_range"] == "O.B.T.O"]["Z-axis"].sum()

  #Counting True + Error orientation:
  true_obto = true_orient[true_orient["Error_range"] == "O.B.T.O"]["Error_range"].count()
  true_owob = true_orient[true_orient["Error_range"] == "O.W.O.B"]["Error_range"].count()
  true_normal = true_orient[true_orient["Error_range"] == "Normal"]["Error_range"].count()
  
  #Calculating the Percentage of True + Error range orientation:
  true_obto_present = (true_obto / true_orient["Error_range"].count()) * 100
  true_owob_present = (true_owob / true_orient["Error_range"].count()) * 100
  true_normal_present = (true_normal / true_orient["Error_range"].count()) * 100

#--------------------------------------------------- False ---------------------------------------------------#

  # Calculating overall True means:

  false_x_axis_mean = false_orient["X-axis"].mean()
  false_y_axis_mean = false_orient["Y-axis"].mean()
  false_z_axis_mean = false_orient["Z-axis"].mean()

  # overall True Summation:
  false_x_axis_sum = false_orient["X-axis"].sum()
  false_y_axis_sum = false_orient["Y-axis"].sum()
  false_z_axis_sum = false_orient["Z-axis"].sum()

  #Counting false + Error range orientation:
  false_low = false_orient[false_orient["Error_range"] == "Low"]["Error_range"].count()
  false_mediam = false_orient[false_orient["Error_range"] == "Mediam"]["Error_range"].count()
  false_high = false_orient[false_orient["Error_range"] == "High"]["Error_range"].count()
  
  #Calculating the Percentage of false + Error range orientation:
  false_low_present = (false_low / false_orient["Error_range"].count()) * 100
  false_mediam_present = (false_mediam / false_orient["Error_range"].count()) * 100
  false_high_present = (false_high / false_orient["Error_range"].count()) * 100

  #Printing Results
  print(format.BLUE +"* "*20, type_,"* "*20 + format.END)
  print(" ")
  print(format.BOLD +"- "*5, "#OVERALL#", "- "*5 + format.END)
  print("Percentage of True orientation =",round(true_present,2), "%", "(count = {})".format(true_count))
  print("Percentage of False orientation =", round(false_present,2), "%", "(count = {})".format(false_count))
  print("X-axis: mean =",round(x_axis_mean,2), " ,sum =",round(x_axis_sum,2))
  print("Y-axis: mean =",round(y_axis_mean,2), " ,sum =",round(y_axis_sum,2))
  print("Z-axis: mean =",round(z_axis_mean,2), " ,sum =",round(z_axis_sum,2))
  print(" ")
  print(format.BOLD + "- "*5, "#TRUE#", "- "*5 + format.END)
  print("X-axis: mean =",round(true_x_axis_mean,2), " ,sum =",round(true_x_axis_sum,2))
  print("Y-axis: mean =",round(true_y_axis_mean,2), " ,sum =",round(true_y_axis_sum,2))
  print("Z-axis: mean =",round(true_z_axis_mean,2), " ,sum =",round(true_z_axis_sum,2))
  print("Percentage of Oriented better than the Original 'O.B.T.O' =", round(true_obto_present,2), "%", "(count = {})".format(true_obto))
  print("Percentage of Originally Wrong and oriented better 'O.W.O.B' =", round(true_owob_present,2),"%", "(count = {})".format(true_owob))
  print("Percentage of Normal orientation =", round(true_normal_present,2), "%", "(count = {})".format(true_normal))
  print(" ")
  print(format.BOLD + "- "*5, "#FALSE#", "- "*5 + format.END)
  print("X-axis: mean =",round(false_x_axis_mean,2), " ,sum =",round(false_x_axis_sum,2))
  print("Y-axis: mean =",round(false_y_axis_mean,2), " ,sum =",round(false_y_axis_sum,2))
  print("Z-axis: mean =",round(false_z_axis_mean,2), " ,sum =",round(false_z_axis_sum,2))
  print("Percentage of Low error orientation =", round(false_low_present,2), "%", "(count = {})".format(false_low))
  print("Percentage of Mediam error orientation =", round(false_mediam_present,2),"%", "(count = {})".format(false_mediam))
  print("Percentage of High error orientation =", round(false_high_present,2), "%", "(count = {})".format(false_high))
  print(" ")
  print(" ")
# Out:
# * * * * * * * * * * * * * * * * * * * *  Bridge 2 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 72.73 % (count = 8)
# Percentage of False orientation = 27.27 % (count = 3)
# X-axis: mean = -9.64  ,sum = -106
# Y-axis: mean = -4.82  ,sum = -53
# Z-axis: mean = 0.45  ,sum = 5
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -2.38  ,sum = -19
# Y-axis: mean = 0.62  ,sum = 5
# Z-axis: mean = -0.12  ,sum = -1
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 8)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -29.0  ,sum = -87
# Y-axis: mean = -19.33  ,sum = -58
# Z-axis: mean = 2.0  ,sum = 6
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 66.67 % (count = 2)
# Percentage of High error orientation = 33.33 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 3 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 72.73 % (count = 16)
# Percentage of False orientation = 27.27 % (count = 6)
# X-axis: mean = 13.41  ,sum = 295
# Y-axis: mean = 1.36  ,sum = 30
# Z-axis: mean = 0.55  ,sum = 12
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 5.69  ,sum = 91
# Y-axis: mean = 1.56  ,sum = 25
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 16)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 34.0  ,sum = 204
# Y-axis: mean = 0.83  ,sum = 5
# Z-axis: mean = 2.0  ,sum = 12
# Percentage of Low error orientation = 33.33 % (count = 2)
# Percentage of Mediam error orientation = 16.67 % (count = 1)
# Percentage of High error orientation = 50.0 % (count = 3)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 4 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 87.5 % (count = 14)
# Percentage of False orientation = 12.5 % (count = 2)
# X-axis: mean = 9.62  ,sum = 154
# Y-axis: mean = 0.69  ,sum = 11
# Z-axis: mean = 0.19  ,sum = 3
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 4.79  ,sum = 67
# Y-axis: mean = 0.21  ,sum = 3
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 14)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 43.5  ,sum = 87
# Y-axis: mean = 4.0  ,sum = 8
# Z-axis: mean = 1.5  ,sum = 3
# Percentage of Low error orientation = 50.0 % (count = 1)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 50.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 5 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 71.43 % (count = 5)
# Percentage of False orientation = 28.57 % (count = 2)
# X-axis: mean = 4.71  ,sum = 33
# Y-axis: mean = -2.14  ,sum = -15
# Z-axis: mean = -1.0  ,sum = -7
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.2  ,sum = 6
# Y-axis: mean = -0.4  ,sum = -2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 5)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 13.5  ,sum = 27
# Y-axis: mean = -6.5  ,sum = -13
# Z-axis: mean = -3.5  ,sum = -7
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 50.0 % (count = 1)
# Percentage of High error orientation = 50.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 6 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 60.0 % (count = 3)
# Percentage of False orientation = 40.0 % (count = 2)
# X-axis: mean = 30.6  ,sum = 153
# Y-axis: mean = -5.6  ,sum = -28
# Z-axis: mean = -4.4  ,sum = -22
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 6.0  ,sum = 18
# Y-axis: mean = -1.67  ,sum = -5
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 3)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 67.5  ,sum = 135
# Y-axis: mean = -11.5  ,sum = -23
# Z-axis: mean = -11.0  ,sum = -22
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 100.0 % (count = 2)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 7 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 2)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 0.5  ,sum = 1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.5  ,sum = 1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 8 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 1)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 1.0  ,sum = 1
# Y-axis: mean = -3.0  ,sum = -3
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.0  ,sum = 1
# Y-axis: mean = -3.0  ,sum = -3
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 9 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 2)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = -0.5  ,sum = -1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.5  ,sum = -1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 10 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 1)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 2.0  ,sum = 2
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 2.0  ,sum = 2
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:95: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:97: RuntimeWarning: invalid value encountered in long_scalars
#  Bridge 11 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 2)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 0.5  ,sum = 1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.5  ,sum = 1
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 12 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 75.0 % (count = 3)
# Percentage of False orientation = 25.0 % (count = 1)
# X-axis: mean = 20.25  ,sum = 81
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = -31.75  ,sum = -127
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.33  ,sum = 4
# Y-axis: mean = 0.33  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 3)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 77.0  ,sum = 77
# Y-axis: mean = -1.0  ,sum = -1
# Z-axis: mean = -127.0  ,sum = -127
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 100.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 13 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 2)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = -2.0  ,sum = -4
# Y-axis: mean = -0.5  ,sum = -1
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -2.0  ,sum = -4
# Y-axis: mean = -0.5  ,sum = -1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Bridge 14 * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 50.0 % (count = 1)
# Percentage of False orientation = 50.0 % (count = 1)
# X-axis: mean = 32.0  ,sum = 64
# Y-axis: mean = 47.5  ,sum = 95
# Z-axis: mean = 33.0  ,sum = 66
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 3.0  ,sum = 3
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 61.0  ,sum = 61
# Y-axis: mean = 95.0  ,sum = 95
# Z-axis: mean = 66.0  ,sum = 66
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 100.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Clear Aligner * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 2)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 1.5  ,sum = 3
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.5  ,sum = 3
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Crown Molar * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 50.0 % (count = 12)
# Percentage of False orientation = 50.0 % (count = 12)
# X-axis: mean = -6.83  ,sum = -164
# Y-axis: mean = -2.75  ,sum = -66
# Z-axis: mean = 1.33  ,sum = 32
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.5  ,sum = 18
# Y-axis: mean = 3.17  ,sum = 38
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 12)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -15.17  ,sum = -182
# Y-axis: mean = -8.67  ,sum = -104
# Z-axis: mean = 2.67  ,sum = 32
# Percentage of Low error orientation = 33.33 % (count = 4)
# Percentage of Mediam error orientation = 50.0 % (count = 6)
# Percentage of High error orientation = 16.67 % (count = 2)
#
#
# * * * * * * * * * * * * * * * * * * * *  Crown Tooth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 48.48 % (count = 16)
# Percentage of False orientation = 51.52 % (count = 17)
# X-axis: mean = -8.09  ,sum = -267
# Y-axis: mean = 6.73  ,sum = 222
# Z-axis: mean = -0.73  ,sum = -24
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -1.88  ,sum = -30
# Y-axis: mean = 3.12  ,sum = 50
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 16)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -13.94  ,sum = -237
# Y-axis: mean = 10.12  ,sum = 172
# Z-axis: mean = -1.41  ,sum = -24
# Percentage of Low error orientation = 23.53 % (count = 4)
# Percentage of Mediam error orientation = 41.18 % (count = 7)
# Percentage of High error orientation = 35.29 % (count = 6)
#
#
# * * * * * * * * * * * * * * * * * * * *  Denture Base * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 85.19 % (count = 69)
# Percentage of False orientation = 14.81 % (count = 12)
# X-axis: mean = 5.04  ,sum = 408
# Y-axis: mean = 4.3  ,sum = 348
# Z-axis: mean = 6.53  ,sum = 529
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.52  ,sum = 36
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.14  ,sum = 10
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 69)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 31.0  ,sum = 372
# Y-axis: mean = 29.0  ,sum = 348
# Z-axis: mean = 43.25  ,sum = 519
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 100.0 % (count = 12)
#
#
# * * * * * * * * * * * * * * * * * * * *  Denture Base No Teeth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 100.0 % (count = 3)
# Percentage of False orientation = 0.0 % (count = 0)
# X-axis: mean = 6.33  ,sum = 19
# Y-axis: mean = 0.33  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 6.33  ,sum = 19
# Y-axis: mean = 0.33  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 3)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Low error orientation = nan % (count = 0)
# Percentage of Mediam error orientation = nan % (count = 0)
# Percentage of High error orientation = nan % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Dey Molar * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 92.0 % (count = 23)
# Percentage of False orientation = 8.0 % (count = 2)
# X-axis: mean = -0.2  ,sum = -5
# Y-axis: mean = 0.4  ,sum = 10
# Z-axis: mean = 0.08  ,sum = 2
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.17  ,sum = 4
# Y-axis: mean = 0.35  ,sum = 8
# Z-axis: mean = 0.09  ,sum = 2
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 23)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -4.5  ,sum = -9
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Low error orientation = 100.0 % (count = 2)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 0.0 % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Dey Tooth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 31.03 % (count = 18)
# Percentage of False orientation = 68.97 % (count = 40)
# X-axis: mean = -8.1  ,sum = -470
# Y-axis: mean = 3.9  ,sum = 226
# Z-axis: mean = 7.4  ,sum = 429
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.33  ,sum = -6
# Y-axis: mean = -0.61  ,sum = -11
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 18)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -11.6  ,sum = -464
# Y-axis: mean = 5.92  ,sum = 237
# Z-axis: mean = 10.72  ,sum = 429
# Percentage of Low error orientation = 20.0 % (count = 8)
# Percentage of Mediam error orientation = 62.5 % (count = 25)
# Percentage of High error orientation = 17.5 % (count = 7)
#
#
# * * * * * * * * * * * * * * * * * * * *  Mockup * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 62.1 % (count = 77)
# Percentage of False orientation = 37.9 % (count = 47)
# X-axis: mean = -0.91  ,sum = -113
# Y-axis: mean = 0.76  ,sum = 94
# Z-axis: mean = 2.27  ,sum = 281
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.17  ,sum = 13
# Y-axis: mean = 0.01  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 7.79 % (count = 6)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 92.21 % (count = 71)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -2.68  ,sum = -126
# Y-axis: mean = 1.98  ,sum = 93
# Z-axis: mean = 5.98  ,sum = 281
# Percentage of Low error orientation = 29.79 % (count = 14)
# Percentage of Mediam error orientation = 44.68 % (count = 21)
# Percentage of High error orientation = 25.53 % (count = 12)
#
#
# * * * * * * * * * * * * * * * * * * * *  Mockup Front Lower teeth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 84.15 % (count = 154)
# Percentage of False orientation = 15.85 % (count = 29)
# X-axis: mean = 2.96  ,sum = 541
# Y-axis: mean = -1.19  ,sum = -217
# Z-axis: mean = -0.3  ,sum = -54
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.06  ,sum = 10
# Y-axis: mean = -0.01  ,sum = -1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 9.74 % (count = 15)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 7.14 % (count = 11)
# Percentage of Normal orientation = 83.12 % (count = 128)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 18.31  ,sum = 531
# Y-axis: mean = -7.45  ,sum = -216
# Z-axis: mean = -1.86  ,sum = -54
# Percentage of Low error orientation = 20.69 % (count = 6)
# Percentage of Mediam error orientation = 20.69 % (count = 6)
# Percentage of High error orientation = 58.62 % (count = 17)
#
#
# * * * * * * * * * * * * * * * * * * * *  Mockup Front Upper teeth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 86.34 % (count = 177)
# Percentage of False orientation = 13.66 % (count = 28)
# X-axis: mean = 5.29  ,sum = 1085
# Y-axis: mean = 2.32  ,sum = 476
# Z-axis: mean = 3.92  ,sum = 803
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.17  ,sum = 30
# Y-axis: mean = -0.01  ,sum = -2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 9.04 % (count = 16)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 8.47 % (count = 15)
# Percentage of Normal orientation = 82.49 % (count = 146)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 37.68  ,sum = 1055
# Y-axis: mean = 17.07  ,sum = 478
# Z-axis: mean = 28.68  ,sum = 803
# Percentage of Low error orientation = 3.57 % (count = 1)
# Percentage of Mediam error orientation = 17.86 % (count = 5)
# Percentage of High error orientation = 78.57 % (count = 22)
#
#
# * * * * * * * * * * * * * * * * * * * *  Mockup No teeth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 73.68 % (count = 14)
# Percentage of False orientation = 26.32 % (count = 5)
# X-axis: mean = 16.32  ,sum = 310
# Y-axis: mean = -0.47  ,sum = -9
# Z-axis: mean = -1.26  ,sum = -24
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.93  ,sum = -13
# Y-axis: mean = -0.57  ,sum = -8
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 7.14 % (count = 1)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 7.14 % (count = 1)
# Percentage of Normal orientation = 85.71 % (count = 12)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 64.6  ,sum = 323
# Y-axis: mean = -0.2  ,sum = -1
# Z-axis: mean = -4.8  ,sum = -24
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 20.0 % (count = 1)
# Percentage of High error orientation = 80.0 % (count = 4)
#
#
# * * * * * * * * * * * * * * * * * * * *  Mockup Upper teeth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 40.0 % (count = 2)
# Percentage of False orientation = 60.0 % (count = 3)
# X-axis: mean = 2.0  ,sum = 10
# Y-axis: mean = 0.2  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 1.0  ,sum = 2
# Y-axis: mean = 0.5  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 50.0 % (count = 1)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 50.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 2.67  ,sum = 8
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Low error orientation = 100.0 % (count = 3)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 0.0 % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Model Base * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 53.33 % (count = 8)
# Percentage of False orientation = 46.67 % (count = 7)
# X-axis: mean = -0.4  ,sum = -6
# Y-axis: mean = 5.93  ,sum = 89
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.38  ,sum = -3
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 12.5 % (count = 1)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 12.5 % (count = 1)
# Percentage of Normal orientation = 75.0 % (count = 6)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -0.43  ,sum = -3
# Y-axis: mean = 12.71  ,sum = 89
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Low error orientation = 71.43 % (count = 5)
# Percentage of Mediam error orientation = 14.29 % (count = 1)
# Percentage of High error orientation = 14.29 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Model side * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 0.0 % (count = 0)
# Percentage of False orientation = 100.0 % (count = 1)
# X-axis: mean = 0.0  ,sum = 0
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = nan  ,sum = 0
# Y-axis: mean = nan  ,sum = 0
# Z-axis: mean = nan  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = nan % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = nan % (count = 0)
# Percentage of Normal orientation = nan % (count = 0)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 0.0  ,sum = 0
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Low error orientation = 100.0 % (count = 1)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 0.0 % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Quadrant * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 60.0 % (count = 3)
# Percentage of False orientation = 40.0 % (count = 2)
# X-axis: mean = 17.4  ,sum = 87
# Y-axis: mean = 18.4  ,sum = 92
# Z-axis: mean = 17.6  ,sum = 88
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.0  ,sum = 0
# Y-axis: mean = 0.33  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 33.33 % (count = 1)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 66.67 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 43.5  ,sum = 87
# Y-axis: mean = 45.5  ,sum = 91
# Z-axis: mean = 44.0  ,sum = 88
# Percentage of Low error orientation = 50.0 % (count = 1)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 50.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Solid Molar * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 58.33 % (count = 7)
# Percentage of False orientation = 41.67 % (count = 5)
# X-axis: mean = -3.08  ,sum = -37
# Y-axis: mean = -3.33  ,sum = -40
# Z-axis: mean = -0.5  ,sum = -6
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.43  ,sum = -3
# Y-axis: mean = -1.0  ,sum = -7
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 71.43 % (count = 5)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 28.57 % (count = 2)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -6.8  ,sum = -34
# Y-axis: mean = -6.6  ,sum = -33
# Z-axis: mean = -1.2  ,sum = -6
# Percentage of Low error orientation = 20.0 % (count = 1)
# Percentage of Mediam error orientation = 60.0 % (count = 3)
# Percentage of High error orientation = 20.0 % (count = 1)
#
#
# * * * * * * * * * * * * * * * * * * * *  Solid Tooth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 33.33 % (count = 4)
# Percentage of False orientation = 66.67 % (count = 8)
# X-axis: mean = -35.67  ,sum = -428
# Y-axis: mean = -4.33  ,sum = -52
# Z-axis: mean = 6.17  ,sum = 74
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.5  ,sum = -2
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 100.0 % (count = 4)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 0.0 % (count = 0)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -53.25  ,sum = -426
# Y-axis: mean = -6.5  ,sum = -52
# Z-axis: mean = 9.25  ,sum = 74
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 37.5 % (count = 3)
# Percentage of High error orientation = 62.5 % (count = 5)
#
#
# * * * * * * * * * * * * * * * * * * * *  Surgical Guide Corner * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 16.96 % (count = 58)
# Percentage of False orientation = 83.04 % (count = 284)
# X-axis: mean = 19.79  ,sum = 6767
# Y-axis: mean = 1.38  ,sum = 472
# Z-axis: mean = 6.86  ,sum = 2345
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 2.12  ,sum = 123
# Y-axis: mean = -3.34  ,sum = -194
# Z-axis: mean = 3.02  ,sum = 175
# Percentage of Oriented better than the Original 'O.B.T.O' = 6.9 % (count = 4)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 1.72 % (count = 1)
# Percentage of Normal orientation = 91.38 % (count = 53)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 23.39  ,sum = 6644
# Y-axis: mean = 2.35  ,sum = 666
# Z-axis: mean = 7.64  ,sum = 2170
# Percentage of Low error orientation = 0.35 % (count = 1)
# Percentage of Mediam error orientation = 7.39 % (count = 21)
# Percentage of High error orientation = 92.25 % (count = 262)
#
#
# * * * * * * * * * * * * * * * * * * * *  Surgical Guide Mockup * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 19.23 % (count = 10)
# Percentage of False orientation = 80.77 % (count = 42)
# X-axis: mean = 14.69  ,sum = 764
# Y-axis: mean = 7.79  ,sum = 405
# Z-axis: mean = 3.17  ,sum = 165
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 0.4  ,sum = 4
# Y-axis: mean = -2.1  ,sum = -21
# Z-axis: mean = 0.2  ,sum = 2
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 10)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 18.1  ,sum = 760
# Y-axis: mean = 10.14  ,sum = 426
# Z-axis: mean = 3.88  ,sum = 163
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 2.38 % (count = 1)
# Percentage of High error orientation = 97.62 % (count = 41)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: RuntimeWarning: invalid value encountered in long_scalars
# * * * * * * * * * * * * * * * * * * * *  Surgical Guide Mockup Front * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 12.5 % (count = 10)
# Percentage of False orientation = 87.5 % (count = 70)
# X-axis: mean = 32.48  ,sum = 2598
# Y-axis: mean = -5.54  ,sum = -443
# Z-axis: mean = 7.97  ,sum = 638
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -2.9  ,sum = -29
# Y-axis: mean = -2.9  ,sum = -29
# Z-axis: mean = 0.2  ,sum = 2
# Percentage of Oriented better than the Original 'O.B.T.O' = 20.0 % (count = 2)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 80.0 % (count = 8)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 37.53  ,sum = 2627
# Y-axis: mean = -5.91  ,sum = -414
# Z-axis: mean = 9.09  ,sum = 636
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 1.43 % (count = 1)
# Percentage of High error orientation = 98.57 % (count = 69)
#
#
# * * * * * * * * * * * * * * * * * * * *  Surgical Guide Side * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 33.33 % (count = 7)
# Percentage of False orientation = 66.67 % (count = 14)
# X-axis: mean = 9.86  ,sum = 207
# Y-axis: mean = 24.76  ,sum = 520
# Z-axis: mean = 8.9  ,sum = 187
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -0.29  ,sum = -2
# Y-axis: mean = 0.29  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 7)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 14.93  ,sum = 209
# Y-axis: mean = 37.0  ,sum = 518
# Z-axis: mean = 13.36  ,sum = 187
# Percentage of Low error orientation = 21.43 % (count = 3)
# Percentage of Mediam error orientation = 21.43 % (count = 3)
# Percentage of High error orientation = 57.14 % (count = 8)
#
#
# * * * * * * * * * * * * * * * * * * * *  Surgical Guide Upper Jaw * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 14.29 % (count = 1)
# Percentage of False orientation = 85.71 % (count = 6)
# X-axis: mean = 5.29  ,sum = 37
# Y-axis: mean = -19.57  ,sum = -137
# Z-axis: mean = 1.57  ,sum = 11
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -5.0  ,sum = -5
# Y-axis: mean = 1.0  ,sum = 1
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 0.0 % (count = 0)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 100.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = 7.0  ,sum = 42
# Y-axis: mean = -23.0  ,sum = -138
# Z-axis: mean = 1.83  ,sum = 11
# Percentage of Low error orientation = 0.0 % (count = 0)
# Percentage of Mediam error orientation = 0.0 % (count = 0)
# Percentage of High error orientation = 100.0 % (count = 6)
#
#
# * * * * * * * * * * * * * * * * * * * *  Temp Crown Molar * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 50.0 % (count = 2)
# Percentage of False orientation = 50.0 % (count = 2)
# X-axis: mean = -2.5  ,sum = -10
# Y-axis: mean = 0.5  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = 2.5  ,sum = 5
# Y-axis: mean = 0.0  ,sum = 0
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Oriented better than the Original 'O.B.T.O' = 50.0 % (count = 1)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 0.0 % (count = 0)
# Percentage of Normal orientation = 50.0 % (count = 1)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -7.5  ,sum = -15
# Y-axis: mean = 1.0  ,sum = 2
# Z-axis: mean = 0.0  ,sum = 0
# Percentage of Low error orientation = 50.0 % (count = 1)
# Percentage of Mediam error orientation = 50.0 % (count = 1)
# Percentage of High error orientation = 0.0 % (count = 0)
#
#
# * * * * * * * * * * * * * * * * * * * *  Temp Crown Tooth * * * * * * * * * * * * * * * * * * * *
#
# - - - - -  #OVERALL# - - - - -
# Percentage of True orientation = 93.18 % (count = 82)
# Percentage of False orientation = 6.82 % (count = 6)
# X-axis: mean = -3.15  ,sum = -277
# Y-axis: mean = -1.0  ,sum = -88
# Z-axis: mean = 0.02  ,sum = 2
#
# - - - - -  #TRUE# - - - - -
# X-axis: mean = -2.23  ,sum = -183
# Y-axis: mean = -0.99  ,sum = -81
# Z-axis: mean = 0.01  ,sum = 1
# Percentage of Oriented better than the Original 'O.B.T.O' = 15.85 % (count = 13)
# Percentage of Originally Wrong and oriented better 'O.W.O.B' = 9.76 % (count = 8)
# Percentage of Normal orientation = 74.39 % (count = 61)
#
# - - - - -  #FALSE# - - - - -
# X-axis: mean = -15.67  ,sum = -94
# Y-axis: mean = -1.17  ,sum = -7
# Z-axis: mean = 0.17  ,sum = 1
# Percentage of Low error orientation = 66.67 % (count = 4)
# Percentage of Mediam error orientation = 33.33 % (count = 2)
# Percentage of High error orientation = 0.0 % (count = 0)
